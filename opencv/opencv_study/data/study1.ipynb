# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
pic = Image.open('/home/seungsu/workspace/opencv/opencv_study/data/lena.jpeg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (220, 220, 3)

# %%
plt.imshow(pic_arr)

# %%
img = cv2.imread('/home/seungsu/workspace/opencv/opencv_study/data/opencv.png')
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (249, 202, 3)

# %%
plt.imshow(img)

# %%
img_gray = cv2.imread('/home/seungsu/workspace/opencv/opencv_study/data/opencv.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap ='gray')

# %%
new_img = cv2.resize(img_gray, (800,600))
plt.imshow(new_img)
